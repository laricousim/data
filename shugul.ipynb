# %%
import pandas as pd

# %%
Guys = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],'Age':[25,30,35,40],'City':['New York', 'Los Angeles', 'Chicago', 'Houston']}

db=pd.DataFrame(Guys)
print(db)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
Titanic = pd.read_csv('./titanic.csv')

Titanic
# Out:
#      "index","pclass","survived","sex","sibsp","parch","embarked"
# 0                        1,"1","1","female","0","0","S"
# 1                          2,"1","1","male","1","2","S"
# 2                        3,"1","0","female","1","2","S"
# 3                          4,"1","0","male","1","2","S"
# 4                        5,"1","0","female","1","2","S"
# ...                                                 ...
# 1304                  1305,"3","0","female","1","0","C"
# 1305                  1306,"3","0","female","1","0","C"
# 1306                    1307,"3","0","male","0","0","C"
# 1307                    1308,"3","0","male","0","0","C"
# 1308                    1309,"3","0","male","0","0","S"
#
# [1309 rows x 1 columns]

# %%
Titanic.head(5)
# Out:
#   "index","pclass","survived","sex","sibsp","parch","embarked"
# 0                     1,"1","1","female","0","0","S"
# 1                       2,"1","1","male","1","2","S"
# 2                     3,"1","0","female","1","2","S"
# 3                       4,"1","0","male","1","2","S"
# 4                     5,"1","0","female","1","2","S"

# %%
TiTan = pd.read_csv('./TITAN.csv')

TiTan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
TiTan.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
AproxAge = TiTan["Age"].mean()

print('the average of the passengers is', AproxAge)
# Out:
# the average of the passengers is 29.69911764705882

# %%
TiTan[TiTan.columns[3]].count()
# Out:
# 891

# %%
TiTan.loc[:,"Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
Survivors = TiTan.loc[TiTan["Survived"]==1]

print(Survivors)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
avgAge = Survivors["Age"].mean()

print(avgAge)
# Out:
# 28.343689655172415

# %%
Survivors.to_csv('survivors.csv')

# %%
AvgAgebyClass = TiTan[['Pclass', 'Age']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Age', ascending=False)

print(AvgAgebyClass)
# Out:
#    Pclass        Age
# 0       1  38.233441
# 1       2  29.877630
# 2       3  25.140620

# %%
AvgAgebyClass.to_excel('average_age_by_class.xlsx')

# %%
#to pick value of each in a particular column

passengerCount = TiTan['Pclass'].value_counts()

print(passengerCount)
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
